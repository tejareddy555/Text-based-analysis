# %% [markdown]
# # Importing pandas and csv file

# %%
import pandas as pd
file = "C:/Users/tejap/Downloads/un-general-debates-blueprint.csv"
df = pd.read_csv(file)
#print top20 rows
df.head(20)
#changess
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %%
df.columns #print columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
df.dtypes #print data types
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df.info() #print info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
df.describe() #print describe
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df['length']=df['text'].str.len() #add column
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
df.describe(include='O') #include objects
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %%
df.isna().sum() #print null values
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %%
df['speaker'].fillna('unknown', inplace=True) #fill missing values
df['position'].fillna('unknown', inplace=True) #fill missing values
df.isna().sum()
# Out:
# C:\Users\tejap\AppData\Local\Temp\ipykernel_10964\4290896531.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['speaker'].fillna('unknown', inplace=True) #fill missing values
# C:\Users\tejap\AppData\Local\Temp\ipykernel_10964\4290896531.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#Uppercase conversion
df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %%
#!pip install matplotlib

# %% [markdown]
# # length plot

# %%
df['length'].plot() #length plot
# Out:
# <Axes: >

# %%
import matplotlib

# %% [markdown]
# # Box Plot

# %%
df['length'].plot(kind='box',vert=False) #box plot
# Out:
# <Axes: >

# %% [markdown]
# # Histogram

# %%
df['length'].plot(kind='hist',bins=30,color='green') #Histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
#!pip install seaborn

# %% [markdown]
# # Box plot

# %%
import seaborn as sns
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box') #box plot
g.fig.set_size_inches(10, 8)
# Out:
# C:\Users\tejap\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
#!pip install regex

# %% [markdown]
# # importing regex functions

# %%
import regex as re

# %%
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov" # Define the test text
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
import nltk
nltk.download('stopwords') # Download stopwords from NLTK
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Print stopwords
# Out:
# {'most', "won't", 'over', 'they', 'is', 'against', 'than', 'at', 'between', 'very', 'off', 't', "wouldn't", 'ain', 's', 'their', "shouldn't", 'into', 'she', 'y', 'hers', 'more', 'our', 'other', 've', 'in', 'who', 'am', 'on', 'too', 'm', "couldn't", 'and', 'no', "don't", "haven't", "needn't", 'below', 'out', "she's", 'being', 'here', 'been', 'of', 'was', 'shan', 'me', 'if', 'having', "didn't", "mightn't", 're', 'again', "weren't", 'his', 'itself', 'own', 'all', "aren't", "it's", 'yours', "hadn't", 'through', 'yourself', 'during', 'just', 'do', 'where', 'have', 'only', 'wouldn', "you'll", 'shouldn', 'those', 'under', 'haven', 'its', "that'll", 'doesn', 'your', 'a', 'such', 'few', "hasn't", 'myself', 'ours', 'by', 'this', 'each', 'about', "you're", 'yourselves', 'll', 'herself', 'you', 'so', 'o', "doesn't", 'after', 'were', 'with', 'don', 'how', 'isn', 'but', 'or', 'once', 'same', 'weren', "shan't", 'some', 'up', 'did', "wasn't", 'mustn', 'these', 'it', 'which', 'has', 'then', 'himself'
# ...

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# %%
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %%
pipeline = [str.lower, tokenize, remove_stop]

# %%
def prepare(text, pipeline):
    tokens = text # Initialize tokens with the input text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens  # Return the processed tokens

# %%
df['tokens'] = df['text'].apply(prepare, pipeline = pipeline)# Apply the prepare function to the 'text' column of the DataFrame

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# ...

# %%
from collections import Counter
tokens = tokenize("She likes my cats and my cats like my sofa.")#tokenize the text
testcount= Counter(tokens)
print(testcount)#print the testcount
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount) # Print the updated counter
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5)) #print the most common 5 tokens
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %%
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq']) # Convert dictionary to DataFrame
freq_df = freq_df.query('freq >= 1') # Filter DataFrame to include only frequencies >= 1
freq_df.index.name = 'token' # Set the name of the index to 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False) # Sort the DataFrame by frequency in descending order

freq_df.head(10)# Display the top 10 rows of the sorted DataFrame
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425

# %%
freq_df.describe()
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))# Plot the top 15 tokens with their frequencies
ax.invert_yaxis()# Invert the y-axis to display the most frequent tokens at the top
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words') 
# Set labels and title for the plot
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
text = df.query("year==2015 and country=='USA'")['text'].values[0]# Select text data for a specific year and country from the DataFrame
plt.figure(figsize=(14, 7))
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')# Display the WordCloud image
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2)# Initialize WordCloud with parameters
wc.fit_words(freq_df['freq'].to_dict() )# Fit WordCloud with frequency dictionary
plt.figure(figsize = (8, 8), facecolor = None)# Set figure size and face color
plt.imshow(wc)
plt.axis("off")# Turn off axis
plt.tight_layout(pad = 0)
plt.show()# Show the WordCloud
