# %% [markdown]
# # ASSIGNMENT 8

# %% [markdown]
# ## NAMED ENTITY RECOGNITION

# %% [markdown]
# ## LOAD SPACY MODELS FOR ENGLISH AND FRENCH

# %% [markdown]
# Spacy is a robust Python natural language processing (NLP) package that excels at processing massive amounts of text data quickly and effectively. It is a well-liked option for NLP jobs because of its strong capabilities for dependency parsing, named entity recognition, tokenization, and part-of-speech tagging.

# %%
# Load Spacy models for processing text in English and French.

import spacy
nlp = spacy.load("en_core_web_lg")
nlp = spacy.load("fr_core_news_lg")

# %% [markdown]
# ## TOKENIZE TEXT

# %%
text = "The sunrise painted the sky in hues of pink and orange, heralding a new day full of possibilities"
doc = nlp(text)
for token in doc:
    print(token, end=" | ")
# Out:
# The | sunrise | painted | the | sky | in | hues | of | pink | and | orange | , | heralding | a | new | day | full | of | possibilities |

# %% [markdown]
# ## GENERATE DATAFRAME FOR TOKEN VISUALIZATION

# %%
# Generate a dataframe for visualizing spaCy tokens with options to include or exclude punctuation.

import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#              text         lemma_  is_stop  is_alpha   pos_          dep_  \
# 0             The            The    False      True      X         nsubj
# 1         sunrise        sunrise    False      True      X  flat:foreign
# 2         painted        painted    False      True      X  flat:foreign
# 3             the            the    False      True      X  flat:foreign
# 4             sky            sky    False      True      X  flat:foreign
# 5              in             in    False      True      X  flat:foreign
# 6            hues           huer    False      True      X  flat:foreign
# 7              of             of    False      True    ADP          case
# 8            pink           pink    False      True  PROPN  flat:foreign
# 9             and            and    False      True      X  flat:foreign
# 10         orange         orange    False      True      X  flat:foreign
# 12      heralding      heralding    False      True  PROPN         appos
# 13              a          avoir     True      True    AUX     aux:tense
# 14            new            new    False      True      X           dep
# 15            day            day    False      True      X           dep
# 16           full           full    False      True      X          ROOT
# 17             of             of    False      True      X          case
# 18  possibilities  possibilities    False      True      X          ROOT
#
#    ent_type_ ent_iob_
# 0       MISC        B
# 1       MISC        I
# 2       MISC        I
# 3       MISC        I
# 4       MISC        I
# 5       MISC        I
# 6       MISC        I
# 7       MISC        I
# 8       MISC        I
# 9       MISC        I
# 10      MISC        I
# 12      MISC        B
# 13      MISC        I
# 14      MISC        I
# 15      MISC        I
# 16      MISC        I
# 17                  O
# 18                  O

# %% [markdown]
# ## FILTER OUT STOP WORDS AND PUNCTUATION

# %% [markdown]
# Words like "and," "the," and "is" are examples of stopwords, which are frequently omitted from text analysis in order to concentrate on important content. Exclamation points, commas, and periods are examples of punctuation marks. These symbols are employed in written language to organize and convey meaning; in text processing jobs, they are frequently eliminated or handled individually.

# %%
# Extract non-stop words and non-punctuation tokens from the given text.

text = "Nestled in the heart of the forest, the ancient oak tree stood tall, its branches whispering secrets of the past to those who would listen"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Nestled, in, the, heart, of, the, forest, the, ancient, oak, tree, stood, tall, its, branches, whispering, secrets, of, the, past, to, those, who, would, listen]

# %% [markdown]
# ## EXTRACT NOUNS FROM TEXT

# %%
# Extract nouns and proper nouns from the given text.

text = "Nestled in the heart of the forest, the ancient oak tree stood tall, its branches whispering secrets of the past to those who would listen"
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [Nestled, stood, tall, branches]

# %% [markdown]
# ## IDENTIFY ENTITIES IN TEXT

# %%
# Print identified entities along with their labels.

text = "Nestled in the heart of the forest, the ancient oak tree stood tall, its branches whispering secrets of the past to those who would listen"
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Nestled in the heart, MISC) (oak tree stood tall, ORG) (its branches whispering secrets of the past to those who would listen, MISC)

# %% [markdown]
# ## IDENTIFY ENTITIES IN TEXT

# %% [markdown]
# Recognizing and classifying particular pieces of information, such as names of individuals, groups, places, dates, and numerical expressions, is necessary to identify entities in text. Deeper semantic analysis and information retrieval are made possible by this procedure, which frequently makes use of named entity recognition (NER) algorithms to automatically extract and classify these entities from a given text corpus.

# %%
# Print identified entities along with their labels.

text = "The gentle hum of the city at night was a comforting reminder of the interconnected lives and stories unfolding within it."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (The gentle hum of the city at night was, MISC) (comforting, PER)

# %% [markdown]
# ## VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the text.

from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The gentle hum of the city at night was
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     comforting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  reminder of the interconnected lives and stories unfolding within it.</div></span>

# %% [markdown]
# ## CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities.

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.thehansindia.com/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 190

# %% [markdown]
# ## VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andhra Pradesh Breaking News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Telangana News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hyderabad News Updates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     National News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breaking News       ePaper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BizzBuzz  hmtv Live Latest NewsHyderabadCricketEntertainmentPhoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  Stories×Festival of DemocracyLatest NewsTelanganaHyderabadAndhra PradeshVisakhapatnamEntertainmentPhoto
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     StoriesDelhi RegionKarnatakaLifestyleWomenEducation &amp; CareersBusinessMedia OutreachSportsEditorialMy VoiceTechnologyMenu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ☰Trending
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  :
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Revanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  ReddyCongressTelangana
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AssemblyLiveKCR’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# s nephew
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanna Rao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  arrested for land-grabbingFree Health Camp organized by Dr
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uday Kumar Dr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  shravaniJago GHMC, urge residents of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steel and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Mines ComplexKCR govt used cops to tap Oppn’s phones to counter them politicallyIndia summons
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  envoy to protest remarks on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kejriwal'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# s arrestED searches for crucial clues at Sri
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saran’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# s residencePM
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Modi’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# s visit cements bilateral ties with BhutanRussian Soyuz rocket with 3 astronauts blasts off to the ISSGold rates in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  slashes, check the rates on 24 March, 2024District
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Vaibhav Gaikwad
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Raghunath
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  started
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the flag march under the
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  auspices of the police departmentJust In KCR’s nephew
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanna Rao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  arrested for land-grabbing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Free Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Camp organized by Dr

# %% [markdown]
# ## COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'MISC': 109, 'PER': 33, 'ORG': 28, 'LOC': 20})

# %% [markdown]
# ## COUNT MOST COMMON ENTITIES

# %%
# Count the most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('March 2024', 4),
#  ('Kanna Rao', 3),
#  ("Kejriwal'", 3),
#  ('Gold rates in', 3),
#  ('Steel and', 2)]

# %% [markdown]
# ## PRINT SPECIFIC SENTENCE

# %%
# Print the 21st sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[20])
# Out:
# In KCR’s nephew Kanna Rao arrested for land-grabbing

# %% [markdown]
# ## VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 21st sentence of the extracted article text.

displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In KCR’s nephew
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kanna Rao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  arrested for land-grabbing </div></span>

# %% [markdown]
# ## EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 21st sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[20])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('In', 'X', 'In'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('KCR’', 'X', 'KCR’'),
#  ('s', 'X', 's'),
#  ('nephew', 'PROPN', 'nephew'),
#  ('Kanna', 'X', 'Kanna'),
#  ('Rao', 'X', 'Rao'),
#  ('arrested', 'X', 'arrested'),
#  ('for', 'X', 'for'),
#  ('land', 'X', 'land'),
#  ('-', 'ADJ', '-'),
#  ('grabbing', 'NOUN', 'grabbing'),
#  ('\xa0', 'SPACE', '\xa0')]

# %% [markdown]
# ## VISUALIZE DEPENDENCY PARSING

# %% [markdown]
# In natural language processing (NLP), dependency parsing is a technique that examines a sentence's grammatical structure by identifying the relationships between words, which are shown as directed edges between tokens in a dependency tree. It makes tasks like semantic analysis, question answering, and machine translation easier by revealing the hierarchical structure and syntactic relationships within phrases.

# %%
# Render a visualization of the dependency parsing for the 21st sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="0d1254f4c099459f9a56cb250dcd09df-0" class="displacy" width="1490" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">KCR’</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">nephew</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Kanna</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Rao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">arrested</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">land-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">grabbing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-0" stroke-width="2px" d="M70,542.0 C70,482.0 130.0,482.0 130.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M130.0,544.0 L138.0,532.0 122.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-1" stroke-width="2px" d="M70,542.0 C70,422.0 255.0,422.0 255.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M255.0,544.0 L263.0,532.0 247.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-2" stroke-width="2px" d="M430,542.0 C430,482.0 490.0,482.0 490.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,544.0 L422,532.0 438,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-3" stroke-width="2px" d="M70,542.0 C70,362.0 500.0,362.0 500.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M500.0,544.0 L508.0,532.0 492.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-4" stroke-width="2px" d="M70,542.0 C70,302.0 625.0,302.0 625.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M625.0,544.0 L633.0,532.0 617.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-5" stroke-width="2px" d="M70,542.0 C70,242.0 750.0,242.0 750.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,544.0 L758.0,532.0 742.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-6" stroke-width="2px" d="M70,542.0 C70,182.0 875.0,182.0 875.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M875.0,544.0 L883.0,532.0 867.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0d1254f4c099459f9a56cb250dcd09df-0-7" stroke-width="2px" d="M70,542.0 C70,122.0 1000.0,122.0 1000.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0d1254f4c099459f9a56cb250dcd09df-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1000.0,544.0 L1008.0,532.0 992.0,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="di

# %% [markdown]
# ## CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://www.thehindu.com/')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 97

# %% [markdown]
# ## VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breaking News Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Top Headlines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , Live Updates | The Hindu
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India World Opinion Elections e-Paper Shorts Data Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Editorial SEARCH FREE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TRIALGIFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subscription Subscribe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  LOGIN ACCOUNT PREMIUM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Open in The Hindu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  AppFREE TRIALLOGINGIFT a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subscription ACCOUNT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  PREMIUM Subscribe
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shorts Data Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Editorial SEARCH
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India World Opinion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Elections e-Paper
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shorts Data Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Editorial
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEARCH News Business Entertainment Life &amp; Style Society
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Technology Videos Podcast Cities States Science Show More Chennai Delhi Bengaluru Hyderabad
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Movies Food Children Data Kochi Books Brandhub
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Coupons Education To enjoy additional benefitsFREE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TRIALGIFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Subscription Subscribe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  LOGIN ACCOUNT PREMIUM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ShowcaseSubscribe to NewslettersCrossword+CONNECT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  WITH
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USIndia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Arvind Kejriwal | The prophet of probity
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Luxury Luxury
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Ayurveda | Is this the year of A-beauty?
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     EnvironmentGoing green | Myriad hues for festival of colours
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  in a non-toxic wayWorld
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     How bad is the humanitarian crisis in Gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ? |
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Explained AAP calls for protest against Kejriwal’
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# s arrest;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi Police
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  beefs up security Heavy personnel deployment and multi-layer barricading have already been put in place on roads leading to the BJP headquarters,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ITO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and in front of the ED office
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PTILive LS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em

# %% [markdown]
# ## COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'MISC': 52, 'ORG': 23, 'LOC': 16, 'PER': 6})

# %% [markdown]
# ## COUNT MOST COMMON ENTITIES

# %%
# Count the 25 most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(25)
# Out:
# [('Tamil Nadu', 3),
#  ('TRIALGIFT', 2),
#  ('Subscription Subscribe', 2),
#  ('Shorts Data Health', 2),
#  ('Delhi Police', 2),
#  ('Cricket IPL', 2),
#  ('The Hindu', 2),
#  ('Breaking News Today', 1),
#  ('Top Headlines', 1),
#  ('India World Opinion Elections e-Paper Shorts Data Health', 1),
#  ('Open in The Hindu', 1),
#  ('Subscription ACCOUNT', 1),
#  ('India World Opinion', 1),
#  ('SEARCH News Business Entertainment Life & Style Society', 1),
#  ('Movies Food Children Data Kochi Books Brandhub', 1),
#  ('ShowcaseSubscribe to NewslettersCrossword+CONNECT', 1),
#  ('USIndia', 1),
#  ('Luxury Luxury', 1),
#  ('EnvironmentGoing green | Myriad hues for festival of colours', 1),
#  ('How bad is the humanitarian crisis in Gaza', 1),
#  ('Explained AAP calls for protest against Kejriwal’', 1),
#  ('ITO', 1),
#  ('PTILive LS', 1),
#  ('BJP likely to release 4th list of candidates today', 1),
#  ('Congress U.P.', 1)]

# %% [markdown]
# ## PRINT SPECIFIC SENTENCE

# %%
# Print the 4th sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[3])
# Out:
# | The Hindu   India World Opinion Elections e-Paper Shorts Data Health

# %% [markdown]
# ## VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 4th sentence of the extracted article text.

displacy.render(nlp(str(sentences[3])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">| The Hindu
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India World Opinion Elections e-Paper Shorts Data Health
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %% [markdown]
# ## EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 4th sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[3])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('The', 'X', 'The'),
#  ('Hindu', 'X', 'Hindu'),
#  ('  ', 'SPACE', '  '),
#  ('India', 'NOUN', 'india'),
#  ('World', 'X', 'World'),
#  ('Opinion', 'NOUN', 'opinion'),
#  ('Elections', 'NOUN', 'election'),
#  ('e-Paper', 'NOUN', 'e-paper'),
#  ('Shorts', 'NOUN', 'short'),
#  ('Data', 'X', 'Data'),
#  ('Health', 'X', 'Health')]

# %% [markdown]
# ## VISUALIZE DEPENDENCY PARSING

# %%
# Render a visualization of the dependency parsing for the 4th sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[3])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="090403024ab049d2a5873039561aa54f-0" class="displacy" width="1490" height="497.0" direction="ltr" style="max-width: none; height: 497.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">|</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">Hindu</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">World</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Opinion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Elections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">e-Paper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Shorts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Data</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="407.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Health</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-0" stroke-width="2px" d="M70,362.0 C70,302.0 145.0,302.0 145.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,364.0 L62,352.0 78,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-1" stroke-width="2px" d="M190,362.0 C190,302.0 265.0,302.0 265.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M265.0,364.0 L273.0,352.0 257.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-2" stroke-width="2px" d="M310,362.0 C310,302.0 385.0,302.0 385.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,364.0 L393.0,352.0 377.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-3" stroke-width="2px" d="M550,362.0 C550,302.0 625.0,302.0 625.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,364.0 L542,352.0 558,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-4" stroke-width="2px" d="M190,362.0 C190,242.0 630.0,242.0 630.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M630.0,364.0 L638.0,352.0 622.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-5" stroke-width="2px" d="M670,362.0 C670,302.0 745.0,302.0 745.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,364.0 L753.0,352.0 737.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-6" stroke-width="2px" d="M670,362.0 C670,242.0 870.0,242.0 870.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870.0,364.0 L878.0,352.0 862.0,352.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-090403024ab049d2a5873039561aa54f-0-7" stroke-width="2px" d="M670,362.0 C670,182.0 995.0,182.0 995.0,362.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-090403024ab049d2a5873039561aa54f-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:foreign</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M995.0,364.0 L1003.0,352.0 987.0,352.0" fill="currentColor"/>
# </g>
#
# <g cl

# %% [markdown]
# ## CONVERT URL TO TEXT AND COUNT ENTITIES

# %%
# Convert the content of a given URL into text and count the identified entities.

from bs4 import BeautifulSoup
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
ny_bb = url_to_string('https://timesofindia.indiatimes.com/us')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 322

# %% [markdown]
# ## VISUALIZE ENTITIES IN TEXT

# %%
# Render a visualization of the identified entities in the extracted article text.

displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US News
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Top News in India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US election news
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Business news
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sports &amp; International News | Times of IndiaEditionUSUSINSun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , 2024 |
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Updated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  10.40AM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ISTRead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ePaperSign
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     InCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther 
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  regionmysurunagpurnashiknavi mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb StoriesBriefsIndiaWorldBusinessSportsCricketEntertainmentAutoTechLife &amp; StylePhotosBlogsAboundePaperTOI+In the NewsSpeaking TreeBihar Board 12th ResultReal EstateIPL Match
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ScheduleIPL 2024India for Financial
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  LiteracyAssam CM
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Himanta Biswa Sarma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  lays down ‘indigenous’ rules for Bangladesh-origin
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MuslimsKejriwal addressed water
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sewer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  issues
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     from ED custody
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AtishiElectoral bonds heroes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  - Men and women who unmasked the secretsCoal production hits 1 billion tonne mark, eases import dependenceIndian grad killed in Pennsylvania car accident;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     consulate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  extends helpCJI:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Was trolled for changing seating position during
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  hearingWill
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kejriwal in jail
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  sway voters? Not a chanceWeekly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Love Horoscope
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  - March 30, 2024:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Read your weekly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5r

# %% [markdown]
# ## COUNT ENTITY LABELS

# %%
# Count the occurrence of each entity label in the extracted article text.

from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'MISC': 166, 'PER': 81, 'ORG': 49, 'LOC': 26})

# %% [markdown]
# ## COUNT MOST COMMON ENTITIES

# %%
# Count the 25 most common entities in the extracted article text.

items = [x.text for x in article.ents]
Counter(items).most_common(25)
# Out:
# [('March 24', 3),
#  ('IPL', 3),
#  ('Read your weekly', 2),
#  ('Facebook & Whatsapp', 2),
#  ('RCB IPL', 2),
#  ("Mustafizur Rahman'", 2),
#  ('world class', 2),
#  ('Yemen by Houthi', 2),
#  ('KKR', 2),
#  ('Pradesh', 2),
#  ('CM Kejriwal', 2),
#  ('by Bollywood', 2),
#  ('How to make', 2),
#  ('US', 2),
#  ('Consulate', 2),
#  ('News', 1),
#  ('US News', 1),
#  ('Top News in India', 1),
#  ('US election news', 1),
#  ('Business news', 1),
#  ('Sports & International News | Times of IndiaEditionUSUSINSun', 1),
#  ('Mar 24', 1),
#  ('Updated', 1),
#  ('ISTRead', 1),
#  ('InCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther ',
#   1)]

# %% [markdown]
# ## PRINT SPECIFIC SENTENCE

# %%
# Print the 26th sentence from the extracted article text.

sentences = [x for x in article.sents]
print(sentences[25])
# Out:
# Not a chanceWeekly Love Horoscope, March 24

# %% [markdown]
# ## VISUALIZE ENTITIES IN SPECIFIC SENTENCE

# %%
# Render a visualization of the identified entities in the 26th sentence of the extracted article text.

displacy.render(nlp(str(sentences[25])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Not a chanceWeekly
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Love Horoscope
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 24
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# </div></span>

# %% [markdown]
# ## EXTRACT WORDS WITH PARTS OF SPEECH AND LEMMAS

# %%
# Extract words along with their parts of speech and lemmas from the 26th sentence of the extracted article text, excluding stop words and punctuation.

[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[25])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Not', 'PROPN', 'Not'),
#  ('chanceWeekly', 'VERB', 'chanceweekly'),
#  ('Love', 'PROPN', 'Love'),
#  ('Horoscope', 'PROPN', 'Horoscope'),
#  ('March', 'PROPN', 'March'),
#  ('24', 'NUM', '24')]

# %% [markdown]
# ## VISUALIZE DEPENDENCY PARSING

# %%
# Render a visualization of the dependency parsing for the 26th sentence of the extracted article text with adjusted distance between words.

displacy.render(nlp(str(sentences[25])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="1c1d23385998459fbf14c16ef2472fa0-0" class="displacy" width="890" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">chanceWeekly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Love</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">Horoscope,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">March</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">24</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-0" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-1" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux:tense</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,184.0 L408.0,172.0 392.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-3" stroke-width="2px" d="M310,182.0 C310,62.0 525.0,62.0 525.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M525.0,184.0 L533.0,172.0 517.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-4" stroke-width="2px" d="M310,182.0 C310,2.0 650.0,2.0 650.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,184.0 L658.0,172.0 642.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1c1d23385998459fbf14c16ef2472fa0-0-5" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1c1d23385998459fbf14c16ef2472fa0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M760.0,184.0 L768.0,172.0 752.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>
